# %%
import requests

# %%
pip install openai
# Out:
# Requirement already satisfied: openai in /root/venv/lib/python3.9/site-packages (0.27.4)
# Requirement already satisfied: requests>=2.20 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openai) (2.28.1)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from openai) (3.8.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openai) (4.64.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.20->openai) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.20->openai) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.20->openai) (2022.9.24)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai) (6.0.2)
# WARNING: You are using pip version 22.0.4; however, version 23.1.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install apikey
# Out:
# Requirement already satisfied: apikey in /root/venv/lib/python3.9/site-packages (0.2.4)
# WARNING: You are using pip version 22.0.4; however, version 23.1.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
openai.api_key = "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"

# %%
import openai
#from apikey import APIKEY


output = openai.ChatCompletion.create(
  model="gpt-3.5-turbo", 
  messages=[{"role": "user", "content": 
             "Write me a summary of \
             El Quijote"}]
)

# Print out the whole output dictionary
print(output)

# Get the output text only
print(output['choices'][0]['message']['content'])
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "El Quijote, also known as Don Quijote de la Mancha, is a famous novel written by Spanish author Miguel de Cervantes in the 17th century. The novel tells the story of a middle-aged gentleman named Alonso Quixano who becomes so immersed in tales of chivalry and adventure that he loses his grip on reality and sets out on a quest to become a knight-errant. \n\nRenaming himself Don Quijote, he recruits a farmer's daughter, Dulcinea, as his lady love and sets out on his adventures accompanied by his loyal squire, Sancho Panza. Along the way, Don Quijote encounters a wide range of characters, some of whom are amused by his antics, while others try to take advantage of his madness. \n\nDespite his delusions, Don Quijote\u2019s adventures have a profound effect on those he encounters, and ultimately he is able to redeem himself by recognizing his own folly. The novel has been praised for its exploration of themes such as reality and illusion, the limits of knowledge and perception, and the power of human imagination. It has become a classic of Spanish literature and is widely considered to be one of the greatest books ever written.",
#         "role": "assistant"
#       }
#     }
#   ],
#   "created": 1682233147,
#   "id": "chatcmpl-78NydSTftLSAAYoSJSOvnw3EviagD",
#   "model": "gpt-3.5-turbo-0301",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 248,
#     "prompt_tokens": 18,
#     "total_tokens": 266
#   }
# }
# El Quijote, also known as Don Quijote de la Mancha, is a famous novel written by Spanish author Miguel de Cervantes in the 17th century. The novel tells the story of a middle-aged gentleman named Alonso Quixano who becomes so immersed in tales of chivalry and adventure that he loses his grip on reality and sets out on a quest to become a knight-errant.
#
# Renaming himself Don Quijote, he recruits a farmer's daughter, Dulcinea, as his lady love and sets out on his adventures accompanied by his loyal squire, Sancho Panza. Along the way, Don Quijote encounters a wide range of characters, some of whom are amused by his antics, while others try to take advantage of his madness.
#
# Despite his delusions, Don Quijote’s adventures have a profound effect on those he encounters, and ultimately he is able to redeem himself by recognizing his own folly. The novel has been praised for its exploration of themes such as reality and illusion, the limits of knowledge and perception, and the power of human imagination. It has become a classic of Spanish literature and is widely considered to be one of the greatest books ever written.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7e14638c-4da2-4339-a6ab-bf433380ccaa' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
